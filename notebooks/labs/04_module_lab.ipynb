# %% [markdown]
# # Module implementation lab
#
# Run the setup cell, complete one challenge at a time, and keep every assertion green. On a phone, use the **⋮** menu to save a copy to Drive first.

# %%
import torch
import torch.nn as nn
print('PyTorch:', torch.__version__)

# %% [markdown]
# ## 1. Fix parameter registration
#
# Predict the result before you run the cell.

# %%
class Broken(nn.Module):
    def __init__(self):
        super().__init__()
        self.weight = torch.randn(3, 2)  # TODO: register this

model = Broken()
print(list(model.named_parameters()))

# %% [markdown]
# ## 2. Save and restore state
#
# Predict the result before you run the cell.

# %%
model = nn.Linear(2, 1)
original = {k: v.clone() for k, v in model.state_dict().items()}

# TODO: change the weights, reload original, and assert equality

# %% [markdown]
# ## 3. See train and eval modes
#
# Predict the result before you run the cell.

# %%
dropout = nn.Dropout(p=0.8)
x = torch.ones(10)

# TODO: run in train mode twice and eval mode twice; compare

# %% [markdown]
# ## 4. Build a nested MLP
#
# Predict the result before you run the cell.

# %%
class TinyMLP(nn.Module):
    def __init__(self):
        super().__init__()
        # TODO: Linear(4, 8), ReLU, Linear(8, 2)

    def forward(self, x):
        # TODO
        pass

# Assert output shape for a (5, 4) batch.

# %% [markdown]
# ## 5. Inspect optimizer references
#
# Predict the result before you run the cell.

# %%
model = nn.Linear(2, 1)
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# TODO: prove the optimizer holds references to the model parameters.

# %% [markdown]
# ## Finish line
#
# Restart the runtime and run all cells. You are done when every cell finishes without an error.
